# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanya-yadav-142/DLAIMLC_202401100400197_TanyaYadav/blob/main/BERT_Lab-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**BERT = Bidirectional Encoder Representations from Transformers**
#
# ##🔧 How it works internally(Sentiment analysis)
# Sentence → Tokenization → BERT → Output (Positive/Negative)
#
# ##How it works internally(Question answering)
# Context + Question → BERT → Find answer span
#
# ###👉 It doesn’t generate new text
# ###👉 It extracts answer from given text
#
# This is called **Extractive Question Answering**

# %% [markdown]
# #🎯 MOST ASKED VIVA QUESTIONS
# ❓ What is pipeline?
#
# 👉 High-level API to use pre-trained models easily
#
# ❓ What is pre-trained model?
#
# 👉 Model already trained on large dataset
#
# ❓ Difference: Sentiment vs QA
# Task	Output
# Sentiment	Positive/Negative
# QA	Extracted answer
# ❓ What is “uncased” vs “cased”?
# uncased → ignores capital letters
# cased → considers capital letters
# 🧠 ONE-LINE MASTER ANSWER
#
# “This code uses Hugging Face pipelines with pre-trained BERT models to perform sentiment classification and extractive question answering without training from scratch.”

# %%
# pip install transformers datasets torch
from transformers import pipeline

# ── Sentiment ──
sent = pipeline("sentiment-analysis", model="textattack/bert-base-uncased-SST-2")
print(sent(["I love this movie!", "This was terrible."]))

# ── Question Answering ──
qa = pipeline("question-answering", model="deepset/bert-base-cased-squad2")
context = "BERT was introduced by Google in 2018. It uses transformer encoders."
print(qa(question="Who made BERT?",  context=context))
print(qa(question="When was BERT made?", context=context))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/477 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# ...
